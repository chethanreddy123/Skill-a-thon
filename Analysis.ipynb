# %%
from gtts import gTTS
import gradio as gr
import os
import speech_recognition as sr
from googletrans import Translator, constants
from pprint import pprint
from moviepy.editor import *

# %%
# coding=utf8
from gtts import gTTS
import gradio as gr
import os
import speech_recognition as sr
from googletrans import Translator, constants
from pprint import pprint
from moviepy.editor import *
def video_to_translate(file_obj,initial_language,final_language):
# Insert Local Video File Path
    videoclip = VideoFileClip(file_obj.name)
    # Insert Local Audio File Path
    videoclip.audio.write_audiofile("test.wav",codec='pcm_s16le')
# initialize the recognizer
    r = sr.Recognizer()

    if initial_language == "English":
        lang_in='en-US'
    elif initial_language == "Italian":
        lang_in='it-IT'
    elif initial_language == "Spanish":
        lang_in='es-MX'
    elif initial_language == "Russian":
        lang_in='ru-RU'
    elif initial_language == "German":
        lang_in='de-DE'
    elif initial_language == "Japanese":
        lang_in='ja-JP'
    # open the file
    with sr.AudioFile("test.wav") as source:
        # listen for the data (load audio to memory)
        audio_data = r.record(source)
        # recognize (convert from speech to text)
        text = r.recognize_google(audio_data, language = lang_in)

    if final_language == "English":
        lang='en'
    elif final_language == "Italian":
        lang='it'
    elif final_language == "Spanish":
        lang='es'
    elif final_language == "Russian":
        lang='ru'
    elif final_language == "German":
        lang='de'
    elif final_language == "Japanese":
        lang='ja'               
    print(lang)
    # init the Google API translator
    translator = Translator()
    translation = translator.translate(text, dest=lang)
    #translation.text
    trans=translation.text
    myobj = gTTS(text=trans, lang=lang, slow=False) 
    myobj.save("audio.wav") 
    # loading audio file
    audioclip = AudioFileClip("audio.wav")
    
    # adding audio to the video clip
    new_audioclip = CompositeAudioClip([audioclip])
    videoclip.audio = new_audioclip
    new_video="video_translated_"+lang+".mp4"
    videoclip.write_videofile(new_video)
    #return 'audio.wav'
    return new_video

initial_language = gr.inputs.Dropdown(["English","Italian","Japanese","Russian","Spanish","German"])
final_language = gr.inputs.Dropdown([ "Russian","Italian","Spanish","German","English","Japanese"])


gr.Interface(fn = video_to_translate,
            inputs = ['file',initial_language,final_language],
            outputs = 'video', 
            verbose = True,
            title = 'Video Translator',
            description = 'A simple application that translates from English, Italian, Japanese, Russian, Spanish, and German video files to  Italian, Spanish, Russian, English and Japanese. Upload your own file, or click one of the examples to load them. Wait one minute to process.',
            article = 
                        '''<div>
                            <p style="text-align: center"> All you need to do is to upload the mp4 file and hit submit, then wait for compiling. After that click on Play/Pause for listing to the video. The video is saved in an mp4 format.
                            For more information visit <a href="https://ruslanmv.com/">ruslanmv.com</a>
                            </p>
                        </div>''',
            examples=[['obama.mp4',"English",'Spanish'],
                      ['obama.mp4',"English",'Italian'],
                      ['obama.mp4',"English",'German'],
                      ['obama.mp4',"English",'Japanese']
                    ]         
            ).launch()

# %%
import os
import openai


openai.api_key =

Role = "Software Engineer"
Organisation = "Mircosoft"
Stipend = "100k $"
Qulification = "B Tech" 
Contact = "achethanreddy1921@gmail.com"

prompt = f"write a job description that highlights the responsibilities and requirements of the {Role}, as well as the benefits of working at the {Organisation}. Make sure to include the {Stipend}, necessary {Qulification}, and {Contact} information for interested applicants. Your job description should be clear, concise, and engaging, and should attract top talent to your organization."

response = openai.Completion.create(
  model="ada",
  prompt=prompt,
  temperature=0.5,
  max_tokens=100,
  top_p=1,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["\n"]
)

job_description = response.choices[0].text.strip()
print(job_description)

# %%
import openai
openai.api_key =

Role = "Software Engineer"
Organisation = "Mircosoft"
Stipend = "100k $"
Qualification = "B Tech" 
Contact = "achethanreddy1921@gmail.com"


prompt = ( "You have been tasked with creating a job description for a new role at your organization. "
           "The following attributes have been provided: \n"
           f"1. Role: {Role} \n"
           f"2. Organization: {Organisation}  \n"
           f"3. Stipend : {Stipend} \n"
           f"4. Qualification : {Qualification} \n"
           f"5. Contact {Contact} \n\n"
           "Using Text-Davinci-003, write a job description that highlights the responsibilities and requirements of the role, as well as the benefits of working at the organization. "
           "Make sure to include the stipend, necessary qualifications, and contact information for interested applicants. "
           "Your job description should be clear, concise, and engaging, and should attract top talent to your organization.")

response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    temperature=0.5,
    max_tokens=1024,
    n=1,
    stop=None,
)

job_description = response.choices[0].text.strip()
print(job_description)
# Out:
# Microsoft is looking for a highly motivated Software Engineer to join our team. This role offers a competitive stipend of $100K and provides an excellent opportunity to work with cutting-edge technology in a fast-paced environment.
#
# The ideal candidate for this position should have a B.Tech degree in Computer Science or a related field and have a passion for software development. We are looking for an individual who is a problem solver and has the ability to work independently and in a team setting.
#
# The Software Engineer will be responsible for developing software solutions for our customers, as well as creating and maintaining software applications. They will also be responsible for developing and maintaining software development processes, testing and debugging software programs, and providing technical support.
#
# If you are interested in this position, please send your resume and cover letter to achethanreddy1921@gmail.com. We look forward to hearing from you!

# %%
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nMicrosoft is looking for a highly motivated Software Engineer to join our team. This role offers a competitive stipend of $100K and provides an excellent opportunity to work with cutting-edge technology in a fast-paced environment. \n\nThe ideal candidate for this position should have a B.Tech degree in Computer Science or a related field and have a passion for software development. We are looking for an individual who is a problem solver and has the ability to work independently and in a team setting. \n\nThe Software Engineer will be responsible for developing software solutions for our customers, as well as creating and maintaining software applications. They will also be responsible for developing and maintaining software development processes, testing and debugging software programs, and providing technical support.\n\nIf you are interested in this position, please send your resume and cover letter to achethanreddy1921@gmail.com. We look forward to hearing from you!"
#     }
#   ],
#   "created": 1677307045,
#   "id": "cmpl-6niTNAVOUwZkW1VKYIPvCDcW6EqZy",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 190,
#     "prompt_tokens": 154,
#     "total_tokens": 344
#   }
# }

# %%
prompt = ( "You have been tasked with creating a course content. "
           "The following attributes have been provided: \n"
           f"1. Course_Title: {Course_Title} \n"
           f"2. Course Duration: {Course_Duration}  \n"
           f"3. Instructor_Name: {Instructor_Name} \n"
           f"4. Course_Structure  : {Course_Structure} \n\n"
           "Write a complete course content using all the above attributes")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/c2/x_cgj8b10s38q85qqx_c88hr0000gn/T/ipykernel_61781/2157190833.py in <module>
#       1 prompt = ( "You have been tasked with creating a course content. "
#       2            "The following attributes have been provided: \n"
# ----> 3            f"1. Course_Title: {Course_Title} \n"
#       4            f"2. Course Duration: {Course_Duration}  \n"
#       5            f"3. Instructor_Name: {Instructor_Name} \n"
#
# NameError: name 'Course_Title' is not defined

# %%
Course_Title = "Python Basics"
Course_Duration = "20 days"
Instructor_Name = "Chethan Reddy"
Course_Structure = "Day 1 : intro python Day 2: Variables Day 3: Loops"


prompt = ( "Create a comprehensive course content that covers the following attributes:"
           "The following attributes have been provided: \n"
           f"1. Course_Title: {Course_Title} \n"
           f"2. Course Duration: {Course_Duration}  \n"
           f"3. Instructor_Name: {Instructor_Name} \n"
           f"4. Course_Structure  : {Course_Structure} \n\n"
           "Use the Davinci003 model to generate a complete and coherent course content that includes all of the above attributes. The content should be well-structured and easy to follow, catering to both beginners and experts in the field. Ensure that the content is informative, engaging, and covers all the necessary topics to give students a comprehensive understanding of the subject matter.")

# %%
import openai
openai.api_key = "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"


response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    temperature=0.5,
    max_tokens=1024,
    n=1,
    stop=None,
)



Course_description = response.choices[0].text.strip()
print(Course_description)
# Out:
# Python Basics
# Instructor: Chethan Reddy
# Course Duration: 20 days
#
# Day 1: Introduction to Python
# • Overview of Python
# • What is Python?
# • History of Python
# • Advantages of Python
# • Python Environment Setup
# • Python Syntax
# • Python Comments
# • Python Variables
# • Python Data Types
# • Python Operators
#
# Day 2: Variables
# • What are Variables?
# • Declaring Variables
# • Naming Conventions
# • Assigning Values to Variables
# • Variable Scope
# • Accessing Variables
# • Global Variables
# • Local Variables
# • Deleting Variables
#
# Day 3: Loops
# • What are Loops?
# • Types of Loops
# • For Loop
# • While Loop
# • Nested Loops
# • Break Statement
# • Continue Statement
# • Pass Statement
# • Using Loops in Python
#
# Day 4: Control Structures
# • What are Control Structures?
# • If-Else Statements
# • If-Elif-Else Statements
# • Nested If-Else Statements
# • Switch Statements
# • Using Control Structures in Python
#
# Day 5: Functions
# • What are Functions?
# • Defining Functions
# • Calling Functions
# • Parameters and Arguments
# • Return Values
# • Global and Local Variables
# • Anonymous Functions
# • Using Functions in Python
#
# Day 6: Modules
# • What are Modules?
# • Importing Modules
# • Creating Modules
# • Using Modules in Python
#
# Day 7: Strings
# • What are Strings?
# • Working with Strings
# • String Operations
# • String Formatting
# • String Slicing
# • Using Strings in Python
#
# Day 8: Lists
# • What are Lists?
# • Working with Lists
# • List Operations
# • List Slicing
# • List Comprehension
# • Using Lists in Python
#
# Day 9: Tuples
# • What are Tuples?
# • Working with Tuples
# • Tuple Operations
# • Tuple Slicing
# • Using Tuples in Python
#
# Day 10: Dictionaries
# • What are Dictionaries?
# • Working with Dictionaries
# • Dictionary Operations
# • Dictionary Slicing
# • Using Dictionaries in Python
#
# Day 11: Sets
# • What are Sets?
# • Working with Sets
# • Set Operations
# • Set Slicing
# • Using Sets in Python
#
# Day 12: File Handling
# • What is File Handling?
# • Opening and Closing Files
# • Reading and Writing Files
# • File Modes
# • Using File Handling in Python
#
# Day 13: Exception Handling
# • What is Exception Handling?
# • Types of Exceptions
# • Exception Handling Syntax
# • Using Exception Handling in Python
#
# Day 14: Object Oriented Programming
# • What is Object Oriented Programming?
# • Classes and Objects
# • Inheritance
# • Polymorphism
# • Abstraction
# • Encapsulation
# • Using OOP in Python
#
# Day 15: Regular Expressions
# • What are Regular Expressions?
# • Working with Regular Expressions
# • Matching Patterns
# • Searching Patterns
# • Using Regular Expressions in Python
#
# Day 16: Debugging
# • What is Debugging?
# • Debugging Techniques
# • Debugging Tools
# • Using Debugging in Python
#
# Day 17: Database Connectivity
# • What is Database Connectivity?
# • Connecting to a Database
# • Executing Queries
# • Retrieving Data
# • Using Database Connectivity in Python
#
# Day 18: Working with Web Services
# • What are Web Services?
# • Working with SOAP
# • Working with REST
# • Using Web Services in Python
#
# Day 19: Graphical User Interface
# • What is Graphical User Interface?
# • Working with Tkinter
# • Working with PyQt
# • Using GUI in Python
#
# Day 20: Final Project
# • Project Overview
# • Project Requirements
# • Project Design
# • Project Development
# • Project Testing
# • Project Deployment

# %%
TagPrompts = (
    "Can you generate the technical tags for content give below at max 5 tags in an array format"
    f"Course Content : {Course_description}"
    "Want the response in the below format"
    "Array = [List of all the tags]"
)

# %%
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=TagPrompts,
    temperature=0.5,
    max_tokens=1024,
    n=1,
    stop=None,
)

Course_Tags = response.choices[0].text.strip()
Course_Tags.split('=')[0][1:]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/c2/x_cgj8b10s38q85qqx_c88hr0000gn/T/ipykernel_61781/3975789189.py in <module>
# ----> 1 response = openai.Completion.create(
#       2     engine="text-davinci-003",
#       3     prompt=TagPrompts,
#       4     temperature=0.5,
#       5     max_tokens=1024,
#
# /Applications/anaconda3/lib/python3.9/site-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /Applications/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# /Applications/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     215         request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     216     ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 217         result = self.request_raw(
#     218             method.lower(),
#     219             url,
#
# /Applications/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     515             _thread_context.session = _make_session()
#     516         try:
# --> 517             result = _thread_context.session.request(
#     518                 method,
#     519                 abs_url,
#
# /Applications/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /Applications/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /Applications/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# /Applications/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /Applications/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /Applications/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Applications/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /Applications/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# /Applications/anaconda3/lib/python3.9/http/client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# /Applications/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# /Applications/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# /Applications/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import ast
TagList = ast.literal_eval(Course_Tags.split('=')[1][1:])
TagList
# Out:
# ['Python Basics',
#  'Chethan Reddy',
#  '20 days',
#  'Introduction to Python',
#  'Overview of Python',
#  'What is Python?',
#  'History of Python',
#  'Advantages of Python',
#  'Python Environment Setup',
#  'Python Syntax',
#  'Python Comments',
#  'Python Variables',
#  'Python Data Types',
#  'Python Operators',
#  'What are Variables?',
#  'Declaring Variables',
#  'Naming Conventions',
#  'Assigning Values to Variables',
#  'Variable Scope',
#  'Accessing Variables',
#  'Global Variables',
#  'Local Variables',
#  'Deleting Variables',
#  'What are Loops?',
#  'Types of Loops',
#  'For Loop',
#  'While Loop',
#  'Nested Loops',
#  'Break Statement',
#  'Continue Statement',
#  'Pass Statement',
#  'Using Loops in Python',
#  'What are Control Structures?',
#  'If-Else Statements',
#  'If-Elif-Else Statements',
#  'Nested If-Else Statements',
#  'Switch Statements',
#  'Using Control Structures in Python',
#  'What are Functions?',
#  'Defining Functions',
#  'Calling Functions',
#  'Parameters and Arguments',
#  'Return Values',
#  'Global and Local Variables',
#  'Anonymous Functions',
#  'Using Functions in Python',
#  'What are Modules?',
#  'Importing Modules',
#  'Creating Modules',
#  'Using Modules in Python',
#  'What are Strings?',
#  'Working with Strings',
#  'String Operations',
#  'String Formatting',
#  'String Slicing',
#  'Using Strings in Python',
#  'What are Lists?',
#  'Working with Lists',
#  'List Operations',
#  'List Slicing',
#  'List Comprehension',
#  'Using Lists in Python',
#  'What are Tuples?',
#  'Working with Tuples',
#  'Tuple Operations',
#  'Tuple Slicing',
#  'Using Tuples in Python',
#  'What are Dictionaries?',
#  'Working with Dictionaries',
#  'Dictionary Operations',
#  'Dictionary Slicing',
#  'Using Dictionaries in Python',
#  'What are Sets?',
#  'Working with Sets',
#  'Set Operations',
#  'Set Slicing',
#  'Using Sets in Python',
#  'What is File Handling?',
#  'Opening and Closing Files',
#  'Reading and Writing Files',
#  'File Modes',
#  'Using File Handling in Python',
#  'What is Exception Handling?',
#  'Types of Exceptions',
#  'Exception Handling Syntax',
#  'Using Exception Handling in Python',
#  'What is Object Oriented Programming?',
#  'Classes and Objects',
#  'Inheritance',
#  'Polymorphism',
#  'Abstraction',
#  'Encapsulation',
#  'Using OOP in Python',
#  'What are Regular Expressions?',
#  'Working with Regular Expressions',
#  'Matching Patterns',
#  'Searching Patterns',
#  'Using Regular Expressions in Python',
#  'What is Debugging?',
#  'Debugging Techniques',
#  'Debugging Tools',
#  'Using Debugging in Python',
#  'What is Database Connectivity?',
#  'Connecting to a Database',
#  'Executing Queries',
#  'Retrieving Data',
#  'Using Database Connectivity in Python',
#  'What are Web Services?',
#  'Working with SOAP',
#  'Working with REST',
#  'Using Web Services in Python',
#  'What is Graphical User Interface?',
#  'Working with Tkinter',
#  'Working with PyQt',
#  'Using GUI in Python',
#  'Project Overview',
#  'Project Requirements',
#  'Project Design',
#  'Project Development',
#  'Project Testing',
#  'Project Deployment']

# %%
print(Course_Tags.split(":")[1][1:])
# Out:
# ["Python Basics", "Chethan Reddy", "20 days", "Introduction to Python", "Variables", "Loops", "Functions", "Modules", "Working with Files", "Object-Oriented Programming", "Exception Handling", "Working with Databases", "Working with APIs", "Debugging", "Regular Expressions", "Working with Web Applications", "Working with Web Servers", "Working with Web Services", "Working with Web Frameworks", "Working with Graphics", "Working with Data Science", "Working with Machine Learning", "Project"]

# %%
print(type(Array))
# Out:
# <class 'list'>

# %%
Mentor_Name = "Chethan Reddy"
Qualification = "Btech"
Organisation = "DataCamp 5+ year of experience"
Expertise = "Python and ML"
Contact = "achethanreddy1921@gmail.com"

# %%
prompt = (
    "Generate a description for a mentor using the following attributes:"
    f"Mentor Name : {Mentor_Name}"
    f"Qualification : {Qualification}"
    f"Organisation : {Organisation}"
    f"Expertise : {Expertise}"
    f"Contact : {Contact}"
    "Please use these attributes to create a detailed and informative description for the mentor. The description should highlight the mentor's achievements and experience, as well as their commitment to helping others. Please make sure that the language is professional and engaging, catering to both beginners and experts in the field"
)

# %%
import openai
openai.api_key = "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"


response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    temperature=0.5,
    max_tokens=1024,
    n=1,
    stop=None,
)



Mentor_description = response.choices[0].text.strip()
print(Mentor_description)
# Out:
# .
#
# Chethan Reddy is a highly experienced mentor with 5+ years of experience in the field of Python and ML. He holds a Btech degree from a reputed university and is currently associated with DataCamp. He is an expert in Python and ML, and is dedicated to helping others learn and grow in the field. Chethan Reddy has a passion for teaching and is committed to providing guidance and support to those who are looking to learn more about Python and ML. With his extensive knowledge and experience, he is able to provide an in-depth understanding of the subject and help students reach their goals. He is easily accessible via email at achethanreddy1921@gmail.com and is always willing to help those who have any questions or queries.
